# %% [markdown]
# # Building LLM-Powered Applications

# %% [markdown]
# ### Cloud-Hosted vs Local LLMs

# %% [markdown]
# ### Hugging Face: Transfer Learning and Supervised Fine-Tuning

# %% [markdown]
# ### Orchestration: Tool Use and Agents

# %% [markdown]
# ### Prompt-Engineering: The Power of In-Context Learning

# %% [markdown]
# ### Retrieval-Augmented Generation

# %% [markdown]
# ### Evaluation and Debugging
